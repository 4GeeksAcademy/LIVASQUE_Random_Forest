# %% [markdown]
# # Explore here

# %%
import pandas as pd

# 1. Cargamos TUS datos limpios usando el link 'raw' de tu repositorio
url_entrenamiento = "https://raw.githubusercontent.com/lindavasquez28/LIVASQUE_proyecto-derbol_de_decision/refs/heads/main/data/processed/clean_diabetes_train.csv"
url_prueba = "https://raw.githubusercontent.com/lindavasquez28/LIVASQUE_proyecto-derbol_de_decision/refs/heads/main/data/processed/clean_diabetes_test.csv"

datos_entrenamiento = pd.read_csv(url_entrenamiento)
datos_prueba = pd.read_csv(url_prueba)

# 2. Separamos las características (lo que usamos para predecir) de la etiqueta (Outcome)
X_entrenamiento = datos_entrenamiento.drop(["Outcome"], axis = 1)
y_entrenamiento = datos_entrenamiento["Outcome"]

X_prueba = datos_prueba.drop(["Outcome"], axis = 1)
y_prueba = datos_prueba["Outcome"]
